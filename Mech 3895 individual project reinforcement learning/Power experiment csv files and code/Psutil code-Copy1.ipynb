# %%
import os
import gym
from stable_baselines3 import PPO, TD3, DDPG, A2C , DQN, SAC
from stable_baselines3.common.vec_env import DummyVecEnv
from stable_baselines3.common.evaluation import evaluate_policy
import numpy as np
import time
import psutil
import csv

environment_name = 'CartPole-v1'
env = gym.make(environment_name)
env = DummyVecEnv([lambda: env])

algorithms = [PPO, A2C, DQN]

with open('Power consumption experiment with CartPole environment.csv', 'a', newline='') as csvfile:
    writer = csv.writer(csvfile)
    writer.writerow(['algorithm.__name__', 'number_of_episodes', 'elapsed_time_sec', 'power_consumption'])

    for i in range(10000):
        algorithm = np.random.choice(algorithms)
        number_of_episodes = np.random.randint(10000, 1000000)

        print(f"Starting loop {i+1} - Algorithm: {algorithm.__name__}, Episodes: {number_of_episodes}")


        start_time = time.time()
        model = algorithm("MlpPolicy", env, verbose=0)
        model.learn(total_timesteps=number_of_episodes)
        end_time = time.time()
        
        cpu_frequency = psutil.cpu_freq().current

    

        # Calculate the power consumption
        power_consumption = cpu_frequency
        
        elapsed_time_ms = (end_time - start_time) * 1000
        elapsed_time_sec = elapsed_time_ms / 1000

        row = [algorithm.__name__, number_of_episodes, elapsed_time_sec, power_consumption]
        
        # Write the results to a CSV file
        with open('Power consumption experiment with CartPole environment.csv', 'a', newline='') as csvfile:
            writer = csv.writer(csvfile)
            writer.writerow((algorithm.__name__, number_of_episodes, elapsed_time_sec, power_consumption))
        print(f"Finished loop {i+1}")
# Out:
# Starting loop 1 - Algorithm: PPO, Episodes: 930426
# Finished loop 1
# Starting loop 2 - Algorithm: PPO, Episodes: 970163
# Finished loop 2
# Starting loop 3 - Algorithm: DQN, Episodes: 996198
# Finished loop 3
# Starting loop 4 - Algorithm: PPO, Episodes: 706824
# Finished loop 4
# Starting loop 5 - Algorithm: A2C, Episodes: 154446
# Finished loop 5
# Starting loop 6 - Algorithm: A2C, Episodes: 22178
# Finished loop 6
# Starting loop 7 - Algorithm: PPO, Episodes: 277881
# Finished loop 7
# Starting loop 8 - Algorithm: DQN, Episodes: 617360
# Finished loop 8
# Starting loop 9 - Algorithm: DQN, Episodes: 986003
# Finished loop 9
# Starting loop 10 - Algorithm: A2C, Episodes: 662171
# Finished loop 10
# Starting loop 11 - Algorithm: PPO, Episodes: 851348
# Finished loop 11
# Starting loop 12 - Algorithm: PPO, Episodes: 452396
# Finished loop 12
# Starting loop 13 - Algorithm: A2C, Episodes: 344506
# Finished loop 13
# Starting loop 14 - Algorithm: A2C, Episodes: 41162
# Finished loop 14
# Starting loop 15 - Algorithm: A2C, Episodes: 283219
# Finished loop 15
# Starting loop 16 - Algorithm: A2C, Episodes: 671135
# Finished loop 16
# Starting loop 17 - Algorithm: PPO, Episodes: 98688
# Finished loop 17
# Starting loop 18 - Algorithm: DQN, Episodes: 451993
# Finished loop 18
# Starting loop 19 - Algorithm: PPO, Episodes: 34186
# Finished loop 19
# Starting loop 20 - Algorithm: PPO, Episodes: 667324
# Finished loop 20
# Starting loop 21 - Algorithm: DQN, Episodes: 753483
# Finished loop 21
# Starting loop 22 - Algorithm: DQN, Episodes: 867612
# Finished loop 22
# Starting loop 23 - Algorithm: PPO, Episodes: 64152
# Finished loop 23
# Starting loop 24 - Algorithm: PPO, Episodes: 223187
# Finished loop 24
# Starting loop 25 - Algorithm: A2C, Episodes: 882010
# Finished loop 25
# Starting loop 26 - Algorithm: A2C, Episodes: 628002
# Finished loop 26
# Starting loop 27 - Algorithm: A2C, Episodes: 469478
# Finished loop 27
# Starting loop 28 - Algorithm: PPO, Episodes: 418524
# Finished loop 28
# Starting loop 29 - Algorithm: A2C, Episodes: 748464
# Finished loop 29
# Starting loop 30 - Algorithm: A2C, Episodes: 10266
# Finished loop 30
# Starting loop 31 - Algorithm: PPO, Episodes: 257814
# Finished loop 31
# Starting loop 32 - Algorithm: DQN, Episodes: 54619
# Finished loop 32
# Starting loop 33 - Algorithm: A2C, Episodes: 929433
# Finished loop 33
# Starting loop 34 - Algorithm: PPO, Episodes: 427936
# Finished loop 34
# Starting loop 35 - Algorithm: DQN, Episodes: 316216
# Finished loop 35
# Starting loop 36 - Algorithm: DQN, Episodes: 730532
# Finished loop 36
# Starting loop 37 - Algorithm: PPO, Episodes: 189227
# Finished loop 37
# Starting loop 38 - Algorithm: A2C, Episodes: 434447
# Finished loop 38
# Starting loop 39 - Algorithm: A2C, Episodes: 939446
# Finished loop 39
# Starting loop 40 - Algorithm: PPO, Episodes: 842872
# Finished loop 40
# Starting loop 41 - Algorithm: A2C, Episodes: 47241
# Finished loop 41
# Starting loop 42 - Algorithm: PPO, Episodes: 609906
# Finished loop 42
# Starting loop 43 - Algorithm: DQN, Episodes: 274830
# Finished loop 43
# Starting loop 44 - Algorithm: DQN, Episodes: 850261
# Finished loop 44
# Starting loop 45 - Algorithm: A2C, Episodes: 274026
# Finished loop 45
# Starting loop 46 - Algorithm: DQN, Episodes: 633539
# Finished loop 46
# Starting loop 47 - Algorithm: DQN, Episodes: 524560
# Finished loop 47
# Starting loop 48 - Algorithm: A2C, Episodes: 411371
# Finished loop 48
# Starting loop 49 - Algorithm: PPO, Episodes: 481464
# Finished loop 49
# Starting loop 50 - Algorithm: A2C, Episodes: 791389
# Finished loop 50
# Starting loop 51 - Algorithm: DQN, Episodes: 89263
# Finished loop 51
# Starting loop 52 - Algorithm: PPO, Episodes: 462230
# Finished loop 52
# Starting loop 53 - Algorithm: PPO, Episodes: 536379
# Finished loop 53
# Starting loop 54 - Algorithm: A2C, Episodes: 669876
# Finished loop 54
# Starting loop 55 - Algorithm: PPO, Episodes: 329037
# Finished loop 55
# Starting loop 56 - Algorithm: A2C, Episodes: 997048
# Finished loop 56
# Starting loop 57 - Algorithm: A2C, Episodes: 109915
# Finished loop 57
# Starting loop 58 - Algorithm: A2C, Episodes: 891539
# Finished loop 58
# Starting loop 59 - Algorithm: PPO, Episodes: 467743
# Finished loop 59
# Starting loop 60 - Algorithm: DQN, Episodes: 173211
# Finished loop 60
# Starting loop 61 - Algorithm: DQN, Episodes: 734066
# Finished loop 61
# Starting loop 62 - Algorithm: PPO, Episodes: 88646
# Finished loop 62
# Starting loop 63 - Algorithm: A2C, Episodes: 451271
# Finished loop 63
# Starting loop 64 - Algorithm: A2C, Episodes: 663079
# Finished loop 64
# Starting loop 65 - Algorithm: A2C, Episodes: 560670
# Finished loop 65
# Starting loop 66 - Algorithm: PPO, Episodes: 95777
# Finished loop 66
# Starting loop 67 - Algorithm: PPO, Episodes: 383294
# Finished loop 67
# Starting loop 68 - Algorithm: A2C, Episodes: 365335
# Finished loop 68
# Starting loop 69 - Algorithm: A2C, Episodes: 885958
# Finished loop 69
# Starting loop 70 - Algorithm: DQN, Episodes: 953544
# Finished loop 70
# Starting loop 71 - Algorithm: A2C, Episodes: 679953
# Finished loop 71
# Starting loop 72 - Algorithm: PPO, Episodes: 595873
# Finished loop 72
# Starting loop 73 - Algorithm: A2C, Episodes: 243097
# Finished loop 73
# Starting loop 74 - Algorithm: PPO, Episodes: 961119
# Finished loop 74
# Starting loop 75 - Algorithm: PPO, Episodes: 109668
# Finished loop 75
# Starting loop 76 - Algorithm: DQN, Episodes: 458489
# Finished loop 76
# Starting loop 77 - Algorithm: PPO, Episodes: 718256
# Finished loop 77
# Starting loop 78 - Algorithm: PPO, Episodes: 871088
# Finished loop 78
# Starting loop 79 - Algorithm: A2C, Episodes: 45059
# Finished loop 79
# Starting loop 80 - Algorithm: A2C, Episodes: 92323
# Finished loop 80
# Starting loop 81 - Algorithm: A2C, Episodes: 370063
# Finished loop 81
# Starting loop 82 - Algorithm: DQN, Episodes: 169202
# Finished loop 82
# Starting loop 83 - Algorithm: PPO, Episodes: 124224
# Finished loop 83
# Starting loop 84 - Algorithm: DQN, Episodes: 954905
# Finished loop 84
# Starting loop 85 - Algorithm: PPO, Episodes: 43985
# Finished loop 85
# Starting loop 86 - Algorithm: PPO, Episodes: 997613
# Finished loop 86
# Starting loop 87 - Algorithm: A2C, Episodes: 412658
# Finished loop 87
# Starting loop 88 - Algorithm: PPO, Episodes: 390327
# Finished loop 88
# Starting loop 89 - Algorithm: DQN, Episodes: 139856
# Finished loop 89
# Starting loop 90 - Algorithm: PPO, Episodes: 763316
# Finished loop 90
# Starting loop 91 - Algorithm: DQN, Episodes: 195320
# Finished loop 91
# Starting loop 92 - Algorithm: DQN, Episodes: 878751
# Finished loop 92
# Starting loop 93 - Algorithm: PPO, Episodes: 102520
# Finished loop 93
# Starting loop 94 - Algorithm: A2C, Episodes: 848680
# Finished loop 94
# Starting loop 95 - Algorithm: DQN, Episodes: 133791
# Finished loop 95
# Starting loop 96 - Algorithm: PPO, Episodes: 135539
# Finished loop 96
# Starting loop 97 - Algorithm: A2C, Episodes: 33172
# Finished loop 97
# Starting loop 98 - Algorithm: A2C, Episodes: 938307
# Finished loop 98
# Starting loop 99 - Algorithm: DQN, Episodes: 989186
# Finished loop 99
# Starting loop 100 - Algorithm: PPO, Episodes: 989832
# Finished loop 100
# Starting loop 101 - Algorithm: DQN, Episodes: 185337
# Finished loop 101
# Starting loop 102 - Algorithm: A2C, Episodes: 415510
# Finished loop 102
# Starting loop 103 - Algorithm: DQN, Episodes: 776046
# Finished loop 103
# Starting loop 104 - Algorithm: DQN, Episodes: 133834
# Finished loop 104
# Starting loop 105 - Algorithm: A2C, Episodes: 422473
# Finished loop 105
# Starting loop 106 - Algorithm: DQN, Episodes: 578286
# Finished loop 106
# Starting loop 107 - Algorithm: A2C, Episodes: 254007
# Finished loop 107
# Starting loop 108 - Algorithm: A2C, Episodes: 998069
# Finished loop 108
# Starting loop 109 - Algorithm: A2C, Episodes: 994951
# Finished loop 109
# Starting loop 110 - Algorithm: PPO, Episodes: 86950
# Finished loop 110
# Starting loop 111 - Algorithm: A2C, Episodes: 240678
# Finished loop 111
# Starting loop 112 - Algorithm: PPO, Episodes: 545316
# Finished loop 112
# Starting loop 113 - Algorithm: PPO, Episodes: 588740
# Finished loop 113
# Starting loop 114 - Algorithm: A2C, Episodes: 780525
# Finished loop 114
# Starting loop 115 - Algorithm: DQN, Episodes: 882124
# Finished loop 115
# Starting loop 116 - Algorithm: PPO, Episodes: 296546
# Finished loop 116
# Starting loop 117 - Algorithm: PPO, Episodes: 581561
# Finished loop 117
# Starting loop 118 - Algorithm: A2C, Episodes: 321074
# Finished loop 118
# Starting loop 119 - Algorithm: DQN, Episodes: 323150
# Finished loop 119
# Starting loop 120 - Algorithm: A2C, Episodes: 878283
# Finished loop 120
# Starting loop 121 - Algorithm: A2C, Episodes: 147021
# Finished loop 121
# Starting loop 122 - Algorithm: PPO, Episodes: 155188
# Finished loop 122
# Starting loop 123 - Algorithm: A2C, Episodes: 632470
# Finished loop 123
# Starting loop 124 - Algorithm: PPO, Episodes: 237135
# Finished loop 124
# Starting loop 125 - Algorithm: DQN, Episodes: 452948
# Finished loop 125
# Starting loop 126 - Algorithm: A2C, Episodes: 950313
# Finished loop 126
# Starting loop 127 - Algorithm: DQN, Episodes: 232472
# Finished loop 127
# Starting loop 128 - Algorithm: A2C, Episodes: 342371
# Finished loop 128
# Starting loop 129 - Algorithm: DQN, Episodes: 65021
# Finished loop 129
# Starting loop 130 - Algorithm: A2C, Episodes: 819820
# Finished loop 130
# Starting loop 131 - Algorithm: PPO, Episodes: 480944
# Finished loop 131
# Starting loop 132 - Algorithm: A2C, Episodes: 240034
# Finished loop 132
# Starting loop 133 - Algorithm: DQN, Episodes: 808263
# Finished loop 133
# Starting loop 134 - Algorithm: A2C, Episodes: 706913
# Finished loop 134
# Starting loop 135 - Algorithm: A2C, Episodes: 554927
# Finished loop 135
# Starting loop 136 - Algorithm: A2C, Episodes: 553693
# Finished loop 136
# Starting loop 137 - Algorithm: DQN, Episodes: 290732
# Finished loop 137
# Starting loop 138 - Algorithm: PPO, Episodes: 580216
# Finished loop 138
# Starting loop 139 - Algorithm: PPO, Episodes: 604483
# Finished loop 139
# Starting loop 140 - Algorithm: PPO, Episodes: 857466
# Finished loop 140
# Starting loop 141 - Algorithm: PPO, Episodes: 438661
# Finished loop 141
# Starting loop 142 - Algorithm: DQN, Episodes: 93540
# Finished loop 142
# Starting loop 143 - Algorithm: DQN, Episodes: 392839
# Finished loop 143
# Starting loop 144 - Algorithm: PPO, Episodes: 45747
# Finished loop 144
# Starting loop 145 - Algorithm: DQN, Episodes: 432946
# Finished loop 145
# Starting loop 146 - Algorithm: PPO, Episodes: 25285
# Finished loop 146
# Starting loop 147 - Algorithm: PPO, Episodes: 216806
# Finished loop 147
# Starting loop 148 - Algorithm: PPO, Episodes: 948234
# Finished loop 148
# Starting loop 149 - Algorithm: A2C, Episodes: 735915
# Finished loop 149
# Starting loop 150 - Algorithm: PPO, Episodes: 190276
# Finished loop 150
# Starting loop 151 - Algorithm: PPO, Episodes: 804522
# Finished loop 151
# Starting loop 152 - Algorithm: PPO, Episodes: 698430
# Finished loop 152
# Starting loop 153 - Algorithm: PPO, Episodes: 158934
# Finished loop 153
# Starting loop 154 - Algorithm: PPO, Episodes: 503417
# Finished loop 154
# Starting loop 155 - Algorithm: DQN, Episodes: 279720
# Finished loop 155
# Starting loop 156 - Algorithm: A2C, Episodes: 992934
# Finished loop 156
# Starting loop 157 - Algorithm: DQN, Episodes: 255645
# Finished loop 157
# Starting loop 158 - Algorithm: PPO, Episodes: 789237
# Finished loop 158
# Starting loop 159 - Algorithm: DQN, Episodes: 893566
# Finished loop 159
# Starting loop 160 - Algorithm: PPO, Episodes: 418056
# Finished loop 160
# Starting loop 161 - Algorithm: DQN, Episodes: 194727
# Finished loop 161
# Starting loop 162 - Algorithm: DQN, Episodes: 464149
# Finished loop 162
# Starting loop 163 - Algorithm: PPO, Episodes: 436425
# Finished loop 163
# Starting loop 164 - Algorithm: DQN, Episodes: 639299
# Finished loop 164
# Starting loop 165 - Algorithm: PPO, Episodes: 227417
# Finished loop 165
# Starting loop 166 - Algorithm: A2C, Episodes: 945002
# Finished loop 166
# Starting loop 167 - Algorithm: PPO, Episodes: 587380
# Finished loop 167
# Starting loop 168 - Algorithm: PPO, Episodes: 424043
# Finished loop 168
# Starting loop 169 - Algorithm: DQN, Episodes: 457912
# Finished loop 169
# Starting loop 170 - Algorithm: DQN, Episodes: 793902
# Finished loop 170
# Starting loop 171 - Algorithm: DQN, Episodes: 950564
# Finished loop 171
# Starting loop 172 - Algorithm: A2C, Episodes: 407986
# Finished loop 172
# Starting loop 173 - Algorithm: DQN, Episodes: 635355
# Finished loop 173
# Starting loop 174 - Algorithm: PPO, Episodes: 727753
# Finished loop 174
# Starting loop 175 - Algorithm: DQN, Episodes: 438759
# Finished loop 175
# Starting loop 176 - Algorithm: A2C, Episodes: 264766
# Finished loop 176
# Starting loop 177 - Algorithm: A2C, Episodes: 226046
# Finished loop 177
# Starting loop 178 - Algorithm: PPO, Episodes: 755111
# Finished loop 178
# Starting loop 179 - Algorithm: PPO, Episodes: 498839
# Finished loop 179
# Starting loop 180 - Algorithm: PPO, Episodes: 873426
# Finished loop 180
# Starting loop 181 - Algorithm: PPO, Episodes: 497450
# Finished loop 181
# Starting loop 182 - Algorithm: A2C, Episodes: 377494
# Finished loop 182
# Starting loop 183 - Algorithm: A2C, Episodes: 308648
# Finished loop 183
# Starting loop 184 - Algorithm: A2C, Episodes: 840453
# Finished loop 184
# Starting loop 185 - Algorithm: DQN, Episodes: 359662
# Finished loop 185
# Starting loop 186 - Algorithm: PPO, Episodes: 89217
# Finished loop 186
# Starting loop 187 - Algorithm: PPO, Episodes: 532745
# Finished loop 187
# Starting loop 188 - Algorithm: DQN, Episodes: 747988
# Finished loop 188
# Starting loop 189 - Algorithm: A2C, Episodes: 258967
# Finished loop 189
# Starting loop 190 - Algorithm: A2C, Episodes: 102141
# Finished loop 190
# Starting loop 191 - Algorithm: DQN, Episodes: 512498
# Finished loop 191
# Starting loop 192 - Algorithm: PPO, Episodes: 675499
# Finished loop 192
# Starting loop 193 - Algorithm: A2C, Episodes: 909538
# Finished loop 193
# Starting loop 194 - Algorithm: A2C, Episodes: 251427
# Finished loop 194
# Starting loop 195 - Algorithm: A2C, Episodes: 684579
# Finished loop 195
# Starting loop 196 - Algorithm: PPO, Episodes: 612252
# Finished loop 196
# Starting loop 197 - Algorithm: DQN, Episodes: 686163
# Finished loop 197
# Starting loop 198 - Algorithm: DQN, Episodes: 198856
# Finished loop 198
# Starting loop 199 - Algorithm: PPO, Episodes: 169970
# Finished loop 199
# Starting loop 200 - Algorithm: PPO, Episodes: 612048
# Finished loop 200
# Starting loop 201 - Algorithm: A2C, Episodes: 301569
# Finished loop 201
# Starting loop 202 - Algorithm: PPO, Episodes: 180803
# Finished loop 202
# Starting loop 203 - Algorithm: DQN, Episodes: 372605
# Finished loop 203
# Starting loop 204 - Algorithm: PPO, Episodes: 872352
# Finished loop 204
# Starting loop 205 - Algorithm: PPO, Episodes: 777165
# Finished loop 205
# Starting loop 206 - Algorithm: DQN, Episodes: 486066
# Finished loop 206
# Starting loop 207 - Algorithm: A2C, Episodes: 348186
# Finished loop 207
# Starting loop 208 - Algorithm: PPO, Episodes: 22916
# Finished loop 208
# Starting loop 209 - Algorithm: A2C, Episodes: 200454
# Finished loop 209
# Starting loop 210 - Algorithm: DQN, Episodes: 544745
# Finished loop 210
# Starting loop 211 - Algorithm: A2C, Episodes: 435571
# Finished loop 211
# Starting loop 212 - Algorithm: A2C, Episodes: 586186
# Finished loop 212
# Starting loop 213 - Algorithm: DQN, Episodes: 383239
# Finished loop 213
# Starting loop 214 - Algorithm: PPO, Episodes: 482751
# Finished loop 214
# Starting loop 215 - Algorithm: A2C, Episodes: 744251
# Finished loop 215
# Starting loop 216 - Algorithm: A2C, Episodes: 484612
# Finished loop 216
# Starting loop 217 - Algorithm: PPO, Episodes: 565725
# Finished loop 217
# Starting loop 218 - Algorithm: PPO, Episodes: 740902
# Finished loop 218
# Starting loop 219 - Algorithm: PPO, Episodes: 399335
# Finished loop 219
# Starting loop 220 - Algorithm: DQN, Episodes: 993123
# Finished loop 220
# Starting loop 221 - Algorithm: PPO, Episodes: 26659
# Finished loop 221
# Starting loop 222 - Algorithm: DQN, Episodes: 580125
# Finished loop 222
# Starting loop 223 - Algorithm: A2C, Episodes: 169711
# Finished loop 223
# Starting loop 224 - Algorithm: PPO, Episodes: 738930
# Finished loop 224
# Starting loop 225 - Algorithm: PPO, Episodes: 544881
# Finished loop 225
# Starting loop 226 - Algorithm: DQN, Episodes: 545986
# Finished loop 226
# Starting loop 227 - Algorithm: A2C, Episodes: 931142
# Finished loop 227
# Starting loop 228 - Algorithm: PPO, Episodes: 356600
# Finished loop 228
# Starting loop 229 - Algorithm: A2C, Episodes: 868170
# Finished loop 229
# Starting loop 230 - Algorithm: PPO, Episodes: 582006
# Finished loop 230
# Starting loop 231 - Algorithm: A2C, Episodes: 606849
# Finished loop 231
# Starting loop 232 - Algorithm: PPO, Episodes: 804117
# Finished loop 232
# Starting loop 233 - Algorithm: A2C, Episodes: 711934
# Finished loop 233
# Starting loop 234 - Algorithm: PPO, Episodes: 456662
# Finished loop 234
# Starting loop 235 - Algorithm: DQN, Episodes: 170895
# Finished loop 235
# Starting loop 236 - Algorithm: DQN, Episodes: 804695
# Finished loop 236
# Starting loop 237 - Algorithm: DQN, Episodes: 572075
# Finished loop 237
# Starting loop 238 - Algorithm: PPO, Episodes: 455039
# Finished loop 238
# Starting loop 239 - Algorithm: A2C, Episodes: 489519
# Finished loop 239
# Starting loop 240 - Algorithm: DQN, Episodes: 62120
# Finished loop 240
# Starting loop 241 - Algorithm: PPO, Episodes: 706920
# Finished loop 241
# Starting loop 242 - Algorithm: DQN, Episodes: 761501
# Finished loop 242
# Starting loop 243 - Algorithm: A2C, Episodes: 976340
# Finished loop 243
# Starting loop 244 - Algorithm: A2C, Episodes: 73777
# Finished loop 244
# Starting loop 245 - Algorithm: DQN, Episodes: 290352
# Finished loop 245
# Starting loop 246 - Algorithm: PPO, Episodes: 376466
# Finished loop 246
# Starting loop 247 - Algorithm: DQN, Episodes: 48441
# Finished loop 247
# Starting loop 248 - Algorithm: DQN, Episodes: 496671
# Finished loop 248
# Starting loop 249 - Algorithm: A2C, Episodes: 662650
# Finished loop 249
# Starting loop 250 - Algorithm: DQN, Episodes: 77129
# Finished loop 250
# Starting loop 251 - Algorithm: A2C, Episodes: 574245
# Finished loop 251
# Starting loop 252 - Algorithm: DQN, Episodes: 272502
# Finished loop 252
# Starting loop 253 - Algorithm: DQN, Episodes: 605512
# Finished loop 253
# Starting loop 254 - Algorithm: A2C, Episodes: 400531
# Finished loop 254
# Starting loop 255 - Algorithm: A2C, Episodes: 335765
# Finished loop 255
# Starting loop 256 - Algorithm: A2C, Episodes: 838517
# Finished loop 256
# Starting loop 257 - Algorithm: DQN, Episodes: 595471
# Finished loop 257
# Starting loop 258 - Algorithm: PPO, Episodes: 396487
# Finished loop 258
# Starting loop 259 - Algorithm: PPO, Episodes: 836801
# Finished loop 259
# Starting loop 260 - Algorithm: A2C, Episodes: 799533
# Finished loop 260
# Starting loop 261 - Algorithm: A2C, Episodes: 485002
# Finished loop 261
# Starting loop 262 - Algorithm: DQN, Episodes: 882465
# Finished loop 262
# Starting loop 263 - Algorithm: A2C, Episodes: 214712
# Finished loop 263
# Starting loop 264 - Algorithm: PPO, Episodes: 713628
# Finished loop 264
# Starting loop 265 - Algorithm: A2C, Episodes: 45365
# Finished loop 265
# Starting loop 266 - Algorithm: PPO, Episodes: 681026
# Finished loop 266
# Starting loop 267 - Algorithm: A2C, Episodes: 582173
# Finished loop 267
# Starting loop 268 - Algorithm: A2C, Episodes: 510463
# Finished loop 268
# Starting loop 269 - Algorithm: PPO, Episodes: 403013
# Finished loop 269
# Starting loop 270 - Algorithm: A2C, Episodes: 940681
# Finished loop 270
# Starting loop 271 - Algorithm: DQN, Episodes: 211814
# Finished loop 271
# Starting loop 272 - Algorithm: DQN, Episodes: 329014
# Finished loop 272
# Starting loop 273 - Algorithm: DQN, Episodes: 193343
# Finished loop 273
# Starting loop 274 - Algorithm: PPO, Episodes: 294513
# Finished loop 274
# Starting loop 275 - Algorithm: A2C, Episodes: 610445
# Finished loop 275
# Starting loop 276 - Algorithm: A2C, Episodes: 942610
# Finished loop 276
# Starting loop 277 - Algorithm: DQN, Episodes: 148066
# Finished loop 277
# Starting loop 278 - Algorithm: PPO, Episodes: 495168
# Finished loop 278
# Starting loop 279 - Algorithm: PPO, Episodes: 57135
# Finished loop 279
# Starting loop 280 - Algorithm: DQN, Episodes: 868888
# Finished loop 280
# Starting loop 281 - Algorithm: DQN, Episodes: 585632
# Finished loop 281
# Starting loop 282 - Algorithm: DQN, Episodes: 903985
# Finished loop 282
# Starting loop 283 - Algorithm: DQN, Episodes: 73462
# Finished loop 283
# Starting loop 284 - Algorithm: PPO, Episodes: 972937
# Finished loop 284
# Starting loop 285 - Algorithm: A2C, Episodes: 804189
# Finished loop 285
# Starting loop 286 - Algorithm: DQN, Episodes: 430742
# Finished loop 286
# Starting loop 287 - Algorithm: A2C, Episodes: 520608
# Finished loop 287
# Starting loop 288 - Algorithm: PPO, Episodes: 284088
# Finished loop 288
# Starting loop 289 - Algorithm: DQN, Episodes: 826924
# Finished loop 289
# Starting loop 290 - Algorithm: PPO, Episodes: 140676
# Finished loop 290
# Starting loop 291 - Algorithm: A2C, Episodes: 687601
# Finished loop 291
# Starting loop 292 - Algorithm: A2C, Episodes: 480360
# Finished loop 292
# Starting loop 293 - Algorithm: A2C, Episodes: 70282
# Finished loop 293
# Starting loop 294 - Algorithm: A2C, Episodes: 422077
# Finished loop 294
# Starting loop 295 - Algorithm: DQN, Episodes: 654740
# Finished loop 295
# Starting loop 296 - Algorithm: PPO, Episodes: 511976
# Finished loop 296
# Starting loop 297 - Algorithm: A2C, Episodes: 487948
# Finished loop 297
# Starting loop 298 - Algorithm: A2C, Episodes: 813454
# Finished loop 298
# Starting loop 299 - Algorithm: A2C, Episodes: 316006
# Finished loop 299
# Starting loop 300 - Algorithm: PPO, Episodes: 776038
# Finished loop 300
# Starting loop 301 - Algorithm: A2C, Episodes: 594725
# Finished loop 301
# Starting loop 302 - Algorithm: PPO, Episodes: 903279
# Finished loop 302
# Starting loop 303 - Algorithm: DQN, Episodes: 68646
# Finished loop 303
# Starting loop 304 - Algorithm: A2C, Episodes: 123186
# Finished loop 304
# Starting loop 305 - Algorithm: PPO, Episodes: 136960
# Finished loop 305
# Starting loop 306 - Algorithm: PPO, Episodes: 398697
# Finished loop 306
# Starting loop 307 - Algorithm: A2C, Episodes: 938250
