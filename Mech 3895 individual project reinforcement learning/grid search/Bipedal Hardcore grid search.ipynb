# %%
import gym
import random
import csv
import time
from itertools import product
from stable_baselines3 import PPO
from stable_baselines3.common.evaluation import evaluate_policy


# these are the hyperparameters we can edit
learning_rates = [0.1, 0.01, 0.001]
n_steps = [512]
batch_sizes = [128]
gammas = [0.9, 0.95, 0.99, 0.999]
gae_lambdas = [0.95, 0.90, 0.85]
clip_ranges = [0.1, 0.2, 0.3]
ent_coefs = [0.0, 0.1, 0.01]
epsilons = [1e-5, 1e-6]

#648 combinations x 45.5 seconds should be 29484

best_hyperparams = None
best_score = -float('inf')

with open('hyperparam_results_grid_search_bipedal_hardcore_100,000.csv', 'a', newline='') as csvfile:
    writer = csv.writer(csvfile)
    writer.writerow(['learning_rate', 'n_steps', 'batch_size', 'gamma', 'gae_lambda', 'clip_range', 'ent_coef', 'epsilon', 'mean_reward', 'training_time', 'standard deviation'])

    for hyperparams in product(learning_rates, n_steps, batch_sizes, gammas, gae_lambdas, clip_ranges, ent_coefs, epsilons):
        learning_rate, n_steps, batch_size, gamma, gae_lambda, clip_range, ent_coef, epsilon = hyperparams

        from gym.envs.box2d import BipedalWalker

        class BipedalWalkerHardcore(BipedalWalker):
            hardcore = True

            def __init__(self, *args, **kwargs):
                super().__init__(*args, **kwargs)


        environment_name = 'BipedalWalkerHardcore-v3'
        gym.register(
            id=environment_name,
            entry_point='__main__:BipedalWalkerHardcore',
            max_episode_steps=1600,
            reward_threshold=300,
        )

        env = gym.make(environment_name)


        model = PPO('MlpPolicy', env,
                    learning_rate=learning_rate,
                    n_steps=n_steps,
                    batch_size=batch_size,
                    gamma=gamma,
                    gae_lambda=gae_lambda,
                    clip_range=clip_range,
                    ent_coef=ent_coef,
                    clip_range_vf=epsilon,
                    verbose=1)

        print("Training with hyperparameters:", hyperparams)

        start_time = time.time()
        model.learn(total_timesteps=100000) #100 thousand steps
        end_time = time.time()

        training_time = end_time - start_time

        mean_reward, std_reward = evaluate_policy(model, env, n_eval_episodes=10)
        print("Mean reward: {:.2f} +/- {:.2f}".format(mean_reward, std_reward))

        if mean_reward > best_score:
            best_hyperparams = hyperparams
            best_score = mean_reward
            print("New best hyperparameters found:", best_hyperparams)
            print("New best score found:", best_score)

        with open('hyperparam_results_grid_search_bipedal_hardcore_100,000.csv', 'a', newline='') as csvfile:
            writer = csv.writer(csvfile)
            writer.writerow((learning_rate, n_steps, batch_size, gamma, gae_lambda, clip_range, ent_coef, epsilon, mean_reward,training_time, std_reward))

    print("Best hyperparameters:", best_hyperparams)
    print("Best score:", best_score)
# Out:
# /home/csacoa/anaconda3/envs/rl2/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment BipedalWalkerHardcore-v3
#   logger.warn("Overriding environment {}".format(id))
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Training with hyperparameters: (0.1, 512, 128, 0.9, 0.95, 0.1, 0.0, 1e-05)
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 74.8     |
# |    ep_rew_mean     | -112     |
# | time/              |          |
# |    fps             | 1524     |
# |    iterations      | 1        |
# |    time_elapsed    | 0        |
# |    total_timesteps | 512      |
# ---------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 74.8      |
# |    ep_rew_mean          | -112      |
# | time/                   |           |
# |    fps                  | 1388      |
# |    iterations           | 2         |
# |    time_elapsed         | 0         |
# |    total_timesteps      | 1024      |
# | train/                  |           |
# |    approx_kl            | 255.04086 |
# |    clip_fraction        | 0.974     |
# |    clip_range           | 0.1       |
# |    clip_range_vf        | 1e-05     |
# |    entropy_loss         | -7.07     |
# |    explained_variance   | -0.00771  |
# |    learning_rate        | 0.1       |
# |    loss                 | 211       |
# |    n_updates            | 10        |
# |    policy_gradient_loss | 0.281     |
# |    std                  | 1.65      |
# |    value_loss           | 376       |
# ---------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 137      |
# |    ep_rew_mean          | -120     |
# | time/                   |          |
# |    fps                  | 1355     |
# |    iterations           | 3        |
# |    time_elapsed         | 1        |
# |    total_timesteps      | 1536     |
# | train/                  |          |
# |    approx_kl            | 579.7932 |
# |    clip_fraction        | 0.956    |
# |    clip_range           | 0.1      |
# |    clip_range_vf        | 1e-05    |
# |    entropy_loss         | -7.28    |
# |    explained_variance   | -0.0672  |
# |    learning_rate        | 0.1      |
# |    loss                 | 40.8     |
# |    n_updates            | 20       |
# |    policy_gradient_loss | 0.195    |
# |    std                  | 1.66     |
# |    value_loss           | 81.4     |
# --------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 102      |
# |    ep_rew_mean          | -120     |
# | time/                   |          |
# |    fps                  | 1340     |
# |    iterations           | 4        |
# |    time_elapsed         | 1        |
# |    total_timesteps      | 2048     |
# | train/                  |          |
# |    approx_kl            | 193.2723 |
# |    clip_fraction        | 0.965    |
# |    clip_range           | 0.1      |
# |    clip_range_vf        | 1e-05    |
# |    entropy_loss         | -7.66    |
# |    explained_variance   | 0.00285  |
# |    learning_rate        | 0.1      |
# |    loss                 | 526      |
# |    n_updates            | 30       |
# |    policy_gradient_loss | 0.266    |
# |    std                  | 2.03     |
# |    value_loss           | 1.23e+03 |
# --------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 102      |
# |    ep_rew_mean          | -120     |
# | time/                   |          |
# |    fps                  | 1326     |
# |    iterations           | 5        |
# |    time_elapsed         | 1        |
# |    total_timesteps      | 2560     |
# | train/                  |          |
# |    approx_kl            | 6530.052 |
# |    clip_fraction        | 0.955    |
# |    clip_range           | 0.1      |
# |    clip_range_vf        | 1e-05    |
# |    entropy_loss         | -8.17    |
# |    explained_variance   | -0.446   |
# |    learning_rate        | 0.1      |
# |    loss                 | 254      |
# |    n_updates            | 40       |
# |    policy_gradient_loss | 0.295    |
# |    std                  | 2.75     |
# |    value_loss           | 671      |
# --------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 125      |
# |    ep_rew_mean          | -123     |
# | time/                   |          |
# |    fps                  | 1316     |
# |    iterations           | 6        |
# |    time_elapsed         | 2        |
# |    total_timesteps      | 3072     |
# | train/                  |          |
# |    approx_kl            | 7241.402 |
# |    clip_fraction        | 0.972    |
# |    clip_range           | 0.1      |
# |    clip_range_vf        | 1e-05    |
# |    entropy_loss         | -8.22    |
# |    explained_variance   | -30.5    |
# |    learning_rate        | 0.1      |
# |    loss                 | 50.7     |
# |    n_updates            | 50       |
# |    policy_gradient_loss | 0.395    |
# |    std                  | 2.69     |
# |    value_loss           | 104      |
# --------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 147      |
# |    ep_rew_mean          | -124     |
# | time/                   |          |
# |    fps                  | 1310     |
# |    iterations           | 7        |
# |    time_elapsed         | 2        |
# |    total_timesteps      | 3584     |
# | train/                  |          |
# |    approx_kl            | 2220.079 |
# |    clip_fraction        | 0.956    |
# |    clip_range           | 0.1      |
# |    clip_range_vf        | 1e-05    |
# |    entropy_loss         | -8.88    |
# |    explained_variance   | -0.254   |
# |    learning_rate        | 0.1      |
# |    loss                 | 76       |
# |    n_updates            | 60       |
# |    policy_gradient_loss | 0.261    |
# |    std                  | 3.37     |
# |    value_loss           | 127      |
# --------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 140       |
# |    ep_rew_mean          | -123      |
# | time/                   |           |
# |    fps                  | 1295      |
# |    iterations           | 8         |
# |    time_elapsed         | 3         |
# |    total_timesteps      | 4096      |
# | train/                  |           |
# |    approx_kl            | 1384.4124 |
# |    clip_fraction        | 0.971     |
# |    clip_range           | 0.1       |
# |    clip_range_vf        | 1e-05     |
# |    entropy_loss         | -9.3      |
# |    explained_variance   | -0.134    |
# |    learning_rate        | 0.1       |
# |    loss                 | 175       |
# |    n_updates            | 70        |
# |    policy_gradient_loss | 0.212     |
# |    std                  | 3.21      |
# |    value_loss           | 342       |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 126       |
# |    ep_rew_mean          | -120      |
# | time/                   |           |
# |    fps                  | 1296      |
# |    iterations           | 9         |
# |    time_elapsed         | 3         |
# |    total_timesteps      | 4608      |
# | train/                  |           |
# |    approx_kl            | 1454.1953 |
# |    clip_fraction        | 0.961     |
# |    clip_range           | 0.1       |
# |    clip_range_vf        | 1e-05     |
# |    entropy_loss         | -10.1     |
# |    explained_variance   | -0.61     |
# |    learning_rate        | 0.1       |
# |    loss                 | 351       |
# |    n_updates            | 80        |
# |    policy_gradient_loss | 0.24      |
# |    std                  | 4.44      |
# |    value_loss           | 682       |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 125       |
# |    ep_rew_mean          | -120      |
# | time/                   |           |
# |    fps                  | 1295      |
# |    iterations           | 10        |
# |    time_elapsed         | 3         |
# |    total_timesteps      | 5120      |
# | train/                  |           |
# |    approx_kl            | 954.66534 |
# |    clip_fraction        | 0.963     |
# |    clip_range           | 0.1       |
# |    clip_range_vf        | 1e-05     |
# |    entropy_loss         | -9.94     |
# |    explained_variance   | 0.00618   |
# |    learning_rate        | 0.1       |
# |    loss                 | 316       |
# |    n_updates            | 90        |
# |    policy_gradient_loss | 0.275     |
# |    std                  | 4.04      |
# |    value_loss           | 636       |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 125       |
# |    ep_rew_mean          | -120      |
# | time/                   |           |
# |    fps                  | 1282      |
# |    iterations           | 11        |
# |    time_elapsed         | 4         |
# |    total_timesteps      | 5632      |
# | train/                  |           |
# |    approx_kl            | 126.10528 |
# |    clip_fraction        | 0.954     |
# |    clip_range           | 0.1       |
# |    clip_range_vf        | 1e-05     |
# |    entropy_loss         | -11.3     |
# |    explained_variance   | -8.26e-05 |
# |    learning_rate        | 0.1       |
# |    loss                 | 328       |
# |    n_updates            | 100       |
# |    policy_gradient_loss | 0.193     |
# |    std                  | 11.6      |
# |    value_loss           | 642       |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 125       |
# |    ep_rew_mean          | -120      |
# | time/                   |           |
# |    fps                  | 1279      |
# |    iterations           | 12        |
# |    time_elapsed         | 4         |
# |    total_timesteps      | 6144      |
# | train/                  |           |
# |    approx_kl            | 4057.92   |
# |    clip_fraction        | 0.951     |
# |    clip_range           | 0.1       |
# |    clip_range_vf        | 1e-05     |
# |    entropy_loss         | -10.2     |
# |    explained_variance   | -1.19e-07 |
# |    learning_rate        | 0.1       |
# |    loss                 | 9.52      |
# |    n_updates            | 110       |
# |    policy_gradient_loss | 0.134     |
# |    std                  | 4.38      |
# |    value_loss           | 18.6      |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 163       |
# |    ep_rew_mean          | -122      |
# | time/                   |           |
# |    fps                  | 1274      |
# |    iterations           | 13        |
# |    time_elapsed         | 5         |
# |    total_timesteps      | 6656      |
# | train/                  |           |
# |    approx_kl            | 7455.082  |
# |    clip_fraction        | 0.965     |
# |    clip_range           | 0.1       |
# |    clip_range_vf        | 1e-05     |
# |    entropy_loss         | -9.52     |
# |    explained_variance   | -1.19e-07 |
# |    learning_rate        | 0.1       |
# |    loss                 | 320       |
# |    n_updates            | 120       |
# |    policy_gradient_loss | 0.134     |
# |    std                  | 5.02      |
# |    value_loss           | 639       |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 163       |
# |    ep_rew_mean          | -122      |
# | time/                   |           |
# |    fps                  | 1264      |
# |    iterations           | 14        |
# |    time_elapsed         | 5         |
# |    total_timesteps      | 7168      |
# | train/                  |           |
# |    approx_kl            | 2828.8384 |
# |    clip_fraction        | 0.964     |
# |    clip_range           | 0.1       |
# |    clip_range_vf        | 1e-05     |
# |    entropy_loss         | -9.63     |
# |    explained_variance   | 0         |
# |    learning_rate        | 0.1       |
# |    loss                 | 8.8       |
# |    n_updates            | 130       |
# |    policy_gradient_loss | 0.19      |
# |    std                  | 4.82      |
# |    value_loss           | 16.8      |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 163       |
# |    ep_rew_mean          | -122      |
# | time/                   |           |
# |    fps                  | 1261      |
# |    iterations           | 15        |
# |    time_elapsed         | 6         |
# |    total_timesteps      | 7680      |
# | train/                  |           |
# |    approx_kl            | 6417.9067 |
# |    clip_fraction        | 0.957     |
# |    clip_range           | 0.1       |
# |    clip_range_vf        | 1e-05     |
# |    entropy_loss         | -8.15     |
# |    explained_variance   | 0         |
# |    learning_rate        | 0.1       |
# |    loss                 | 313       |
# |    n_updates            | 140       |
# |    policy_gradient_loss | 0.132     |
# |    std                  | 2.74      |
# |    value_loss           | 626       |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 199       |
# |    ep_rew_mean          | -123      |
# | time/                   |           |
# |    fps                  | 1267      |
# |    iterations           | 16        |
# |    time_elapsed         | 6         |
# |    total_timesteps      | 8192      |
# | train/                  |           |
# |    approx_kl            | 2656.4673 |
# |    clip_fraction        | 0.971     |
# |    clip_range           | 0.1       |
# |    clip_range_vf        | 1e-05     |
# |    entropy_loss         | -7.52     |
# |    explained_variance   | 6.56e-07  |
# |    learning_rate        | 0.1       |
# |    loss                 | 7.34      |
# |    n_updates            | 150       |
# |    policy_gradient_loss | 0.14      |
# |    std                  | 2.49      |
# |    value_loss           | 14.5      |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 199       |
# |    ep_rew_mean          | -123      |
# | time/                   |           |
# |    fps                  | 1267      |
# |    iterations           | 17        |
# |    time_elapsed         | 6         |
# |    total_timesteps      | 8704      |
# | train/                  |           |
# |    approx_kl            | 3149.1904 |
# |    clip_fraction        | 0.955     |
# |    clip_range           | 0.1       |
# |    clip_range_vf        | 1e-05     |
# |    entropy_loss         | -8.39     |
# |    explained_variance   | 2.98e-07  |
# |    learning_rate        | 0.1       |
# |    loss                 | 307       |
# |    n_updates            | 160       |
# |    policy_gradient_loss | 0.176     |
# |    std                  | 5.4       |
# |    value_loss           | 604       |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 199       |
# |    ep_rew_mean          | -123      |
# | time/                   |           |
# |    fps                  | 1247      |
# |    iterations           | 18        |
# |    time_elapsed         | 7         |
# |    total_timesteps      | 9216      |
# | train/                  |           |
# |    approx_kl            | 3160.1426 |
# |    clip_fraction        | 0.969     |
# |    clip_range           | 0.1       |
# |    clip_range_vf        | 1e-05     |
# |    entropy_loss         | -8.92     |
# |    explained_variance   | 2.38e-07  |
# |    learning_rate        | 0.1       |
# |    loss                 | 6.92      |
# |    n_updates            | 170       |
# |    policy_gradient_loss | 0.136     |
# |    std                  | 5.3       |
# |    value_loss           | 13.5      |
# ---------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 233      |
# |    ep_rew_mean          | -125     |
# | time/                   |          |
# |    fps                  | 1250     |
# |    iterations           | 19       |
# |    time_elapsed         | 7        |
# |    total_timesteps      | 9728     |
# | train/                  |          |
# |    approx_kl            | 8628.809 |
# |    clip_fraction        | 0.961    |
# |    clip_range           | 0.1      |
# |    clip_range_vf        | 1e-05    |
# |    entropy_loss         | -8       |
# |    explained_variance   | 0        |
# |    learning_rate        | 0.1      |
# |    loss                 | 307      |
# |    n_updates            | 180      |
# |    policy_gradient_loss | 0.138    |
# |    std                  | 2.08     |
# |    value_loss           | 609      |
# --------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 233       |
# |    ep_rew_mean          | -125      |
# | time/                   |           |
# |    fps                  | 1254      |
# |    iterations           | 20        |
# |    time_elapsed         | 8         |
# |    total_timesteps      | 10240     |
# | train/                  |           |
# |    approx_kl            | 7727.2114 |
# |    clip_fraction        | 0.967     |
# |    clip_range           | 0.1       |
# |    clip_range_vf        | 1e-05     |
# |    entropy_loss         | -7.24     |
# |    explained_variance   | -2.38e-07 |
# |    learning_rate        | 0.1       |
# |    loss                 | 6.47      |
# |    n_updates            | 190       |
# |    policy_gradient_loss | 0.172     |
# |    std                  | 1.71      |
# |    value_loss           | 12.7      |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 233       |
# |    ep_rew_mean          | -125      |
# | time/                   |           |
# |    fps                  | 1257      |
# |    iterations           | 21        |
# |    time_elapsed         | 8         |
# |    total_timesteps      | 10752     |
# | train/                  |           |
# |    approx_kl            | 1661.4442 |
# |    clip_fraction        | 0.95      |
# |    clip_range           | 0.1       |
# |    clip_range_vf        | 1e-05     |
# |    entropy_loss         | -7.67     |
# |    explained_variance   | -1.19e-07 |
# |    learning_rate        | 0.1       |
# |    loss                 | 305       |
# |    n_updates            | 200       |
# |    policy_gradient_loss | 0.134     |
# |    std                  | 2         |
# |    value_loss           | 604       |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 262       |
# |    ep_rew_mean          | -126      |
# | time/                   |           |
# |    fps                  | 1259      |
# |    iterations           | 22        |
# |    time_elapsed         | 8         |
# |    total_timesteps      | 11264     |
# | train/                  |           |
# |    approx_kl            | 6346.0737 |
# |    clip_fraction        | 0.963     |
# |    clip_range           | 0.1       |
# |    clip_range_vf        | 1e-05     |
# |    entropy_loss         | -7.03     |
# |    explained_variance   | -1.19e-07 |
# |    learning_rate        | 0.1       |
# |    loss                 | 6.24      |
# |    n_updates            | 210       |
# |    policy_gradient_loss | 0.211     |
# |    std                  | 1.6       |
# |    value_loss           | 11.9      |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 257       |
# |    ep_rew_mean          | -126      |
# | time/                   |           |
# |    fps                  | 1259      |
# |    iterations           | 23        |
# |    time_elapsed         | 9         |
# |    total_timesteps      | 11776     |
# | train/                  |           |
# |    approx_kl            | 8691.756  |
# |    clip_fraction        | 0.963     |
# |    clip_range           | 0.1       |
# |    clip_range_vf        | 1e-05     |
# |    entropy_loss         | -6.86     |
# |    explained_variance   | -5.96e-07 |
# |    learning_rate        | 0.1       |
# |    loss                 | 289       |
# |    n_updates            | 220       |
# |    policy_gradient_loss | 0.173     |
# |    std                  | 1.62      |
# |    value_loss           | 591       |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 257       |
# |    ep_rew_mean          | -126      |
# | time/                   |           |
# |    fps                  | 1260      |
# |    iterations           | 24        |
# |    time_elapsed         | 9         |
# |    total_timesteps      | 12288     |
# | train/                  |           |
# |    approx_kl            | 78611.375 |
# |    clip_fraction        | 0.973     |
# |    clip_range           | 0.1       |
# |    clip_range_vf        | 1e-05     |
# |    entropy_loss         | -6.15     |
# |    explained_variance   | -1.19e-07 |
# |    learning_rate        | 0.1       |
# |    loss                 | 29        |
# |    n_updates            | 230       |
# |    policy_gradient_loss | 0.146     |
# |    std                  | 1.65      |
# |    value_loss           | 95.4      |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 257       |
# |    ep_rew_mean          | -126      |
# | time/                   |           |
# |    fps                  | 1259      |
# |    iterations           | 25        |
# |    time_elapsed         | 10        |
# |    total_timesteps      | 12800     |
# | train/                  |           |
# |    approx_kl            | 49537.883 |
# |    clip_fraction        | 0.974     |
# |    clip_range           | 0.1       |
# |    clip_range_vf        | 1e-05     |
# |    entropy_loss         | -6.11     |
# |    explained_variance   | -2.38e-07 |
# |    learning_rate        | 0.1       |
# |    loss                 | 302       |
# |    n_updates            | 240       |
# |    policy_gradient_loss | 0.134     |
# |    std                  | 1.71      |
# |    value_loss           | 599       |
# ---------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 287      |
# |    ep_rew_mean          | -127     |
# | time/                   |          |
# |    fps                  | 1249     |
# |    iterations           | 26       |
# |    time_elapsed         | 10       |
# |    total_timesteps      | 13312    |
# | train/                  |          |
# |    approx_kl            | 2901.601 |
# |    clip_fraction        | 0.975    |
# |    clip_range           | 0.1      |
# |    clip_range_vf        | 1e-05    |
# |    entropy_loss         | -6.24    |
# |    explained_variance   | 7.75e-07 |
# |    learning_rate        | 0.1      |
# |    loss                 | 6        |
# |    n_updates            | 250      |
# |    policy_gradient_loss | 0.144    |
# |    std                  | 1.72     |
# |    value_loss           | 11.7     |
# --------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 287       |
# |    ep_rew_mean          | -127      |
# | time/                   |           |
# |    fps                  | 1251      |
# |    iterations           | 27        |
# |    time_elapsed         | 11        |
# |    total_timesteps      | 13824     |
# | train/                  |           |
# |    approx_kl            | 28658.023 |
# |    clip_fraction        | 0.973     |
# |    clip_range           | 0.1       |
# |    clip_range_vf        | 1e-05     |
# |    entropy_loss         | -6.46     |
# |    explained_variance   | 0         |
# |    learning_rate        | 0.1       |
# |    loss                 | 277       |
# |    n_updates            | 260       |
# |    policy_gradient_loss | 0.178     |
# |    std                  | 1.74      |
# |    value_loss           | 552       |
# ---------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 287      |
# |    ep_rew_mean          | -127     |
# | time/                   |          |
# |    fps                  | 1253     |
# |    iterations           | 28       |
# |    time_elapsed         | 11       |
# |    total_timesteps      | 14336    |
# | train/                  |          |
# |    approx_kl            | 13336.02 |
# |    clip_fraction        | 0.973    |
# |    clip_range           | 0.1      |
# |    clip_range_vf        | 1e-05    |
# |    entropy_loss         | -6.7     |
# |    explained_variance   | 0        |
# |    learning_rate        | 0.1      |
# |    loss                 | 8.25     |
# |    n_updates            | 270      |
# |    policy_gradient_loss | 0.214    |
# |    std                  | 1.7      |
# |    value_loss           | 16.1     |
# --------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 315      |
# |    ep_rew_mean          | -128     |
# | time/                   |          |
# |    fps                  | 1255     |
# |    iterations           | 29       |
# |    time_elapsed         | 11       |
# |    total_timesteps      | 14848    |
# | train/                  |          |
# |    approx_kl            | 3541.012 |
# |    clip_fraction        | 0.954    |
# |    clip_range           | 0.1      |
# |    clip_range_vf        | 1e-05    |
# |    entropy_loss         | -6.49    |
# |    explained_variance   | 0        |
# |    learning_rate        | 0.1      |
# |    loss                 | 281      |
# |    n_updates            | 280      |
# |    policy_gradient_loss | 0.145    |
# |    std                  | 1.29     |
# |    value_loss           | 560      |
# --------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 315      |
# |    ep_rew_mean          | -128     |
# | time/                   |          |
# |    fps                  | 1257     |
# |    iterations           | 30       |
# |    time_elapsed         | 12       |
# |    total_timesteps      | 15360    |
# | train/                  |          |
# |    approx_kl            | 22153.85 |
# |    clip_fraction        | 0.968    |
# |    clip_range           | 0.1      |
# |    clip_range_vf        | 1e-05    |
# |    entropy_loss         | -5.73    |
# |    explained_variance   | 3.58e-07 |
# |    learning_rate        | 0.1      |
# |    loss                 | 8.15     |
# |    n_updates            | 290      |
# |    policy_gradient_loss | 0.172    |
# |    std                  | 1.84     |
# |    value_loss           | 16       |
# --------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 315       |
# |    ep_rew_mean          | -128      |
# | time/                   |           |
# |    fps                  | 1259      |
# |    iterations           | 31        |
# |    time_elapsed         | 12        |
# |    total_timesteps      | 15872     |
# | train/                  |           |
# |    approx_kl            | 22842.682 |
# |    clip_fraction        | 0.966     |
# |    clip_range           | 0.1       |
# |    clip_range_vf        | 1e-05     |
# |    entropy_loss         | -5.6      |
# |    explained_variance   | 0         |
# |    learning_rate        | 0.1       |
# |    loss                 | 279       |
# |    n_updates            | 300       |
# |    policy_gradient_loss | 0.141     |
# |    std                  | 2.14      |
# |    value_loss           | 559       |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 343       |
# |    ep_rew_mean          | -129      |
# | time/                   |           |
# |    fps                  | 1262      |
# |    iterations           | 32        |
# |    time_elapsed         | 12        |
# |    total_timesteps      | 16384     |
# | train/                  |           |
# |    approx_kl            | 60192.484 |
# |    clip_fraction        | 0.975     |
# |    clip_range           | 0.1       |
# |    clip_range_vf        | 1e-05     |
# |    entropy_loss         | -5.66     |
# |    explained_variance   | 0         |
# |    learning_rate        | 0.1       |
# |    loss                 | 7.99      |
# |    n_updates            | 310       |
# |    policy_gradient_loss | 0.22      |
# |    std                  | 2.37      |
# |    value_loss           | 15.5      |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 343       |
# |    ep_rew_mean          | -129      |
# | time/                   |           |
# |    fps                  | 1264      |
# |    iterations           | 33        |
# |    time_elapsed         | 13        |
# |    total_timesteps      | 16896     |
# | train/                  |           |
# |    approx_kl            | 46194.555 |
# |    clip_fraction        | 0.969     |
# |    clip_range           | 0.1       |
# |    clip_range_vf        | 1e-05     |
# |    entropy_loss         | -5.77     |
# |    explained_variance   | 0         |
# |    learning_rate        | 0.1       |
# |    loss                 | 273       |
# |    n_updates            | 320       |
# |    policy_gradient_loss | 0.177     |
# |    std                  | 2.35      |
# |    value_loss           | 536       |
# ---------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 343      |
# |    ep_rew_mean          | -129     |
# | time/                   |          |
# |    fps                  | 1267     |
# |    iterations           | 34       |
# |    time_elapsed         | 13       |
# |    total_timesteps      | 17408    |
# | train/                  |          |
# |    approx_kl            | 34352.34 |
# |    clip_fraction        | 0.97     |
# |    clip_range           | 0.1      |
# |    clip_range_vf        | 1e-05    |
# |    entropy_loss         | -5.72    |
# |    explained_variance   | 5.96e-08 |
# |    learning_rate        | 0.1      |
# |    loss                 | 8.92     |
# |    n_updates            | 330      |
# |    policy_gradient_loss | 0.136    |
# |    std                  | 2.32     |
# |    value_loss           | 17.5     |
# --------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 369       |
# |    ep_rew_mean          | -130      |
# | time/                   |           |
# |    fps                  | 1266      |
# |    iterations           | 35        |
# |    time_elapsed         | 14        |
# |    total_timesteps      | 17920     |
# | train/                  |           |
# |    approx_kl            | 53342.5   |
# |    clip_fraction        | 0.96      |
# |    clip_range           | 0.1       |
# |    clip_range_vf        | 1e-05     |
# |    entropy_loss         | -5.58     |
# |    explained_variance   | -1.19e-07 |
# |    learning_rate        | 0.1       |
# |    loss                 | 274       |
# |    n_updates            | 340       |
# |    policy_gradient_loss | 0.137     |
# |    std                  | 2.55      |
# |    value_loss           | 546       |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 369       |
# |    ep_rew_mean          | -130      |
# | time/                   |           |
# |    fps                  | 1251      |
# |    iterations           | 36        |
# |    time_elapsed         | 14        |
# |    total_timesteps      | 18432     |
# | train/                  |           |
# |    approx_kl            | 3212.7373 |
# |    clip_fraction        | 0.975     |
# |    clip_range           | 0.1       |
# |    clip_range_vf        | 1e-05     |
# |    entropy_loss         | -5.54     |
# |    explained_variance   | 1.19e-07  |
# |    learning_rate        | 0.1       |
# |    loss                 | 9.23      |
# |    n_updates            | 350       |
# |    policy_gradient_loss | 0.179     |
# |    std                  | 2.54      |
# |    value_loss           | 17.3      |
# ---------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 369      |
# |    ep_rew_mean          | -130     |
# | time/                   |          |
# |    fps                  | 1244     |
# |    iterations           | 37       |
# |    time_elapsed         | 15       |
# |    total_timesteps      | 18944    |
# | train/                  |          |
# |    approx_kl            | 48975.08 |
# |    clip_fraction        | 0.97     |
# |    clip_range           | 0.1      |
# |    clip_range_vf        | 1e-05    |
# |    entropy_loss         | -5.38    |
# |    explained_variance   | 0        |
# |    learning_rate        | 0.1      |
# |    loss                 | 254      |
# |    n_updates            | 360      |
# |    policy_gradient_loss | 0.134    |
# |    std                  | 1.93     |
# |    value_loss           | 510      |
# --------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 388      |
# |    ep_rew_mean          | -130     |
# | time/                   |          |
# |    fps                  | 1243     |
# |    iterations           | 38       |
# |    time_elapsed         | 15       |
# |    total_timesteps      | 19456    |
# | train/                  |          |
# |    approx_kl            | 5719.198 |
# |    clip_fraction        | 0.975    |
# |    clip_range           | 0.1      |
# |    clip_range_vf        | 1e-05    |
# |    entropy_loss         | -6.15    |
# |    explained_variance   | 0        |
# |    learning_rate        | 0.1      |
# |    loss                 | 12.6     |
# |    n_updates            | 370      |
# |    policy_gradient_loss | 0.215    |
# |    std                  | 2.17     |
# |    value_loss           | 25.1     |
# --------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 355       |
# |    ep_rew_mean          | -128      |
# | time/                   |           |
# |    fps                  | 1243      |
# |    iterations           | 39        |
# |    time_elapsed         | 16        |
# |    total_timesteps      | 19968     |
# | train/                  |           |
# |    approx_kl            | 4016.751  |
# |    clip_fraction        | 0.966     |
# |    clip_range           | 0.1       |
# |    clip_range_vf        | 1e-05     |
# |    entropy_loss         | -7.15     |
# |    explained_variance   | -0.000247 |
# |    learning_rate        | 0.1       |
# |    loss                 | 261       |
# |    n_updates            | 380       |
# |    policy_gradient_loss | 0.176     |
# |    std                  | 2.42      |
# |    value_loss           | 490       |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 335       |
# |    ep_rew_mean          | -126      |
# | time/                   |           |
# |    fps                  | 1242      |
# |    iterations           | 40        |
# |    time_elapsed         | 16        |
# |    total_timesteps      | 20480     |
# | train/                  |           |
# |    approx_kl            | 4036.4521 |
# |    clip_fraction        | 0.962     |
# |    clip_range           | 0.1       |
# |    clip_range_vf        | 1e-05     |
# |    entropy_loss         | -7.05     |
# |    explained_variance   | 0         |
# |    learning_rate        | 0.1       |
# |    loss                 | 254       |
# |    n_updates            | 390       |
# |    policy_gradient_loss | 0.265     |
# |    std                  | 2.57      |
# |    value_loss           | 551       |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 312       |
# |    ep_rew_mean          | -124      |
# | time/                   |           |
# |    fps                  | 1242      |
# |    iterations           | 41        |
# |    time_elapsed         | 16        |
# |    total_timesteps      | 20992     |
# | train/                  |           |
# |    approx_kl            | 14722.186 |
# |    clip_fraction        | 0.964     |
# |    clip_range           | 0.1       |
# |    clip_range_vf        | 1e-05     |
# |    entropy_loss         | -7.08     |
# |    explained_variance   | 1.19e-07  |
# |    learning_rate        | 0.1       |
# |    loss                 | 284       |
# |    n_updates            | 400       |
# |    policy_gradient_loss | 0.252     |
# |    std                  | 3.28      |
# |    value_loss           | 539       |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 309       |
# |    ep_rew_mean          | -124      |
# | time/                   |           |
# |    fps                  | 1239      |
# |    iterations           | 42        |
# |    time_elapsed         | 17        |
# |    total_timesteps      | 21504     |
# | train/                  |           |
# |    approx_kl            | 12662.218 |
# |    clip_fraction        | 0.97      |
# |    clip_range           | 0.1       |
# |    clip_range_vf        | 1e-05     |
# |    entropy_loss         | -7.74     |
# |    explained_variance   | -1.19e-07 |
# |    learning_rate        | 0.1       |
# |    loss                 | 272       |
# |    n_updates            | 410       |
# |    policy_gradient_loss | 0.265     |
# |    std                  | 4.44      |
# |    value_loss           | 550       |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 309       |
# |    ep_rew_mean          | -124      |
# | time/                   |           |
# |    fps                  | 1238      |
# |    iterations           | 43        |
# |    time_elapsed         | 17        |
# |    total_timesteps      | 22016     |
# | train/                  |           |
# |    approx_kl            | 5192.1084 |
# |    clip_fraction        | 0.968     |
# |    clip_range           | 0.1       |
# |    clip_range_vf        | 1e-05     |
# |    entropy_loss         | -7.1      |
# |    explained_variance   | -0.205    |
# |    learning_rate        | 0.1       |
# |    loss                 | 245       |
# |    n_updates            | 420       |
# |    policy_gradient_loss | 0.159     |
# |    std                  | 4.73      |
# |    value_loss           | 504       |
# ---------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 309      |
# |    ep_rew_mean          | -124     |
# | time/                   |          |
# |    fps                  | 1238     |
# |    iterations           | 44       |
# |    time_elapsed         | 18       |
# |    total_timesteps      | 22528    |
# | train/                  |          |
# |    approx_kl            | 8679.345 |
# |    clip_fraction        | 0.97     |
# |    clip_range           | 0.1      |
# |    clip_range_vf        | 1e-05    |
# |    entropy_loss         | -7.1     |
# |    explained_variance   | 0        |
# |    learning_rate        | 0.1      |
# |    loss                 | 13       |
# |    n_updates            | 430      |
# |    policy_gradient_loss | 0.133    |
# |    std                  | 4.77     |
# |    value_loss           | 25.7     |
# --------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 328      |
# |    ep_rew_mean          | -125     |
# | time/                   |          |
# |    fps                  | 1238     |
# |    iterations           | 45       |
# |    time_elapsed         | 18       |
# |    total_timesteps      | 23040    |
# | train/                  |          |
# |    approx_kl            | 7666.385 |
# |    clip_fraction        | 0.97     |
# |    clip_range           | 0.1      |
# |    clip_range_vf        | 1e-05    |
# |    entropy_loss         | -7.05    |
# |    explained_variance   | 0        |
# |    learning_rate        | 0.1      |
# |    loss                 | 251      |
# |    n_updates            | 440      |
# |    policy_gradient_loss | 0.135    |
# |    std                  | 5.64     |
# |    value_loss           | 498      |
# --------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 328      |
# |    ep_rew_mean          | -125     |
# | time/                   |          |
# |    fps                  | 1236     |
# |    iterations           | 46       |
# |    time_elapsed         | 19       |
# |    total_timesteps      | 23552    |
# | train/                  |          |
# |    approx_kl            | 4677.909 |
# |    clip_fraction        | 0.973    |
# |    clip_range           | 0.1      |
# |    clip_range_vf        | 1e-05    |
# |    entropy_loss         | -6.99    |
# |    explained_variance   | 0        |
# |    learning_rate        | 0.1      |
# |    loss                 | 13       |
# |    n_updates            | 450      |
# |    policy_gradient_loss | 0.178    |
# |    std                  | 6.03     |
# |    value_loss           | 25.6     |
# --------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 328       |
# |    ep_rew_mean          | -125      |
# | time/                   |           |
# |    fps                  | 1234      |
# |    iterations           | 47        |
# |    time_elapsed         | 19        |
# |    total_timesteps      | 24064     |
# | train/                  |           |
# |    approx_kl            | 9347.83   |
# |    clip_fraction        | 0.964     |
# |    clip_range           | 0.1       |
# |    clip_range_vf        | 1e-05     |
# |    entropy_loss         | -7.18     |
# |    explained_variance   | -1.19e-07 |
# |    learning_rate        | 0.1       |
# |    loss                 | 248       |
# |    n_updates            | 460       |
# |    policy_gradient_loss | 0.134     |
# |    std                  | 9.03      |
# |    value_loss           | 495       |
# ---------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 327      |
# |    ep_rew_mean          | -125     |
# | time/                   |          |
# |    fps                  | 1231     |
# |    iterations           | 48       |
# |    time_elapsed         | 19       |
# |    total_timesteps      | 24576    |
# | train/                  |          |
# |    approx_kl            | 8816.78  |
# |    clip_fraction        | 0.974    |
# |    clip_range           | 0.1      |
# |    clip_range_vf        | 1e-05    |
# |    entropy_loss         | -7.45    |
# |    explained_variance   | 0        |
# |    learning_rate        | 0.1      |
# |    loss                 | 13.2     |
# |    n_updates            | 470      |
# |    policy_gradient_loss | 0.138    |
# |    std                  | 8.36     |
# |    value_loss           | 26.1     |
# --------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 324       |
# |    ep_rew_mean          | -125      |
# | time/                   |           |
# |    fps                  | 1229      |
# |    iterations           | 49        |
# |    time_elapsed         | 20        |
# |    total_timesteps      | 25088     |
# | train/                  |           |
# |    approx_kl            | 15203.404 |
# |    clip_fraction        | 0.969     |
# |    clip_range           | 0.1       |
# |    clip_range_vf        | 1e-05     |
# |    entropy_loss         | -8.46     |
# |    explained_variance   | -0.00779  |
# |    learning_rate        | 0.1       |
# |    loss                 | 234       |
# |    n_updates            | 480       |
# |    policy_gradient_loss | 0.266     |
# |    std                  | 11        |
# |    value_loss           | 529       |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 324       |
# |    ep_rew_mean          | -125      |
# | time/                   |           |
# |    fps                  | 1227      |
# |    iterations           | 50        |
# |    time_elapsed         | 20        |
# |    total_timesteps      | 25600     |
# | train/                  |           |
# |    approx_kl            | 10116.852 |
# |    clip_fraction        | 0.972     |
# |    clip_range           | 0.1       |
# |    clip_range_vf        | 1e-05     |
# |    entropy_loss         | -7.97     |
# |    explained_variance   | 1.19e-07  |
# |    learning_rate        | 0.1       |
# |    loss                 | 27.3      |
# |    n_updates            | 490       |
# |    policy_gradient_loss | 0.137     |
# |    std                  | 8.92      |
# |    value_loss           | 118       |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 324       |
# |    ep_rew_mean          | -125      |
# | time/                   |           |
# |    fps                  | 1227      |
# |    iterations           | 51        |
# |    time_elapsed         | 21        |
# |    total_timesteps      | 26112     |
# | train/                  |           |
# |    approx_kl            | 7298.4434 |
# |    clip_fraction        | 0.957     |
# |    clip_range           | 0.1       |
# |    clip_range_vf        | 1e-05     |
# |    entropy_loss         | -9.26     |
# |    explained_variance   | 0         |
# |    learning_rate        | 0.1       |
# |    loss                 | 247       |
# |    n_updates            | 500       |
# |    policy_gradient_loss | 0.131     |
# |    std                  | 13.3      |
# |    value_loss           | 493       |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 340       |
# |    ep_rew_mean          | -126      |
# | time/                   |           |
# |    fps                  | 1221      |
# |    iterations           | 52        |
# |    time_elapsed         | 21        |
# |    total_timesteps      | 26624     |
# | train/                  |           |
# |    approx_kl            | 14770.322 |
# |    clip_fraction        | 0.971     |
# |    clip_range           | 0.1       |
# |    clip_range_vf        | 1e-05     |
# |    entropy_loss         | -8.86     |
# |    explained_variance   | -1.19e-07 |
# |    learning_rate        | 0.1       |
# |    loss                 | 13.1      |
# |    n_updates            | 510       |
# |    policy_gradient_loss | 0.134     |
# |    std                  | 9.25      |
# |    value_loss           | 26.2      |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 340       |
# |    ep_rew_mean          | -126      |
# | time/                   |           |
# |    fps                  | 1221      |
# |    iterations           | 53        |
# |    time_elapsed         | 22        |
# |    total_timesteps      | 27136     |
# | train/                  |           |
# |    approx_kl            | 4974.7627 |
# |    clip_fraction        | 0.968     |
# |    clip_range           | 0.1       |
# |    clip_range_vf        | 1e-05     |
# |    entropy_loss         | -8.63     |
# |    explained_variance   | 0         |
# |    learning_rate        | 0.1       |
# |    loss                 | 244       |
# ...
# |    std                  | 5.02e+14  |
# |    value_loss           | 594       |
# ---------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 213      |
# |    ep_rew_mean          | -121     |
# | time/                   |          |
# |    fps                  | 1071     |
# |    iterations           | 20       |
# |    time_elapsed         | 9        |
# |    total_timesteps      | 10240    |
# | train/                  |          |
# |    approx_kl            | 3.849464 |
# |    clip_fraction        | 0.927    |
# |    clip_range           | 0.1      |
# |    clip_range_vf        | 1e-05    |
# |    entropy_loss         | -140     |
# |    explained_variance   | 0.000387 |
# |    learning_rate        | 0.1      |
# |    loss                 | 345      |
# |    n_updates            | 190      |
# |    policy_gradient_loss | 0.17     |
# |    std                  | 2.32e+15 |
# |    value_loss           | 606      |
# --------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 194          |
# |    ep_rew_mean          | -120         |
# | time/                   |              |
# |    fps                  | 1070         |
# |    iterations           | 21           |
# |    time_elapsed         | 10           |
# |    total_timesteps      | 10752        |
# | train/                  |              |
# |    approx_kl            | 0.0040175174 |
# |    clip_fraction        | 0.332        |
# |    clip_range           | 0.1          |
# |    clip_range_vf        | 1e-05        |
# |    entropy_loss         | -144         |
# |    explained_variance   | 0.00395      |
# |    learning_rate        | 0.1          |
# |    loss                 | 265          |
# |    n_updates            | 200          |
# |    policy_gradient_loss | 0.025        |
# |    std                  | 2.42e+15     |
# |    value_loss           | 574          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 194         |
# |    ep_rew_mean          | -120        |
# | time/                   |             |
# |    fps                  | 1069        |
# |    iterations           | 22          |
# |    time_elapsed         | 10          |
# |    total_timesteps      | 11264       |
# | train/                  |             |
# |    approx_kl            | 0.013846478 |
# |    clip_fraction        | 0.559       |
# |    clip_range           | 0.1         |
# |    clip_range_vf        | 1e-05       |
# |    entropy_loss         | -144        |
# |    explained_variance   | 0.0023      |
# |    learning_rate        | 0.1         |
# |    loss                 | 240         |
# |    n_updates            | 210         |
# |    policy_gradient_loss | 0.0161      |
# |    std                  | 2.52e+15    |
# |    value_loss           | 620         |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 200       |
# |    ep_rew_mean          | -121      |
# | time/                   |           |
# |    fps                  | 1068      |
# |    iterations           | 23        |
# |    time_elapsed         | 11        |
# |    total_timesteps      | 11776     |
# | train/                  |           |
# |    approx_kl            | 1.0782106 |
# |    clip_fraction        | 0.785     |
# |    clip_range           | 0.1       |
# |    clip_range_vf        | 1e-05     |
# |    entropy_loss         | -145      |
# |    explained_variance   | -0.0147   |
# |    learning_rate        | 0.1       |
# |    loss                 | 280       |
# |    n_updates            | 220       |
# |    policy_gradient_loss | 0.0791    |
# |    std                  | 6.73e+15  |
# |    value_loss           | 585       |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -121        |
# | time/                   |             |
# |    fps                  | 1067        |
# |    iterations           | 24          |
# |    time_elapsed         | 11          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.011566289 |
# |    clip_fraction        | 0.752       |
# |    clip_range           | 0.1         |
# |    clip_range_vf        | 1e-05       |
# |    entropy_loss         | -148        |
# |    explained_variance   | 1.85e-06    |
# |    learning_rate        | 0.1         |
# |    loss                 | 159         |
# |    n_updates            | 230         |
# |    policy_gradient_loss | 0.0561      |
# |    std                  | 6.54e+15    |
# |    value_loss           | 266         |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 216       |
# |    ep_rew_mean          | -123      |
# | time/                   |           |
# |    fps                  | 1067      |
# |    iterations           | 25        |
# |    time_elapsed         | 11        |
# |    total_timesteps      | 12800     |
# | train/                  |           |
# |    approx_kl            | 1.5971036 |
# |    clip_fraction        | 0.789     |
# |    clip_range           | 0.1       |
# |    clip_range_vf        | 1e-05     |
# |    entropy_loss         | -149      |
# |    explained_variance   | 7.02e-05  |
# |    learning_rate        | 0.1       |
# |    loss                 | 279       |
# |    n_updates            | 240       |
# |    policy_gradient_loss | 0.0824    |
# |    std                  | 1.9e+16   |
# |    value_loss           | 590       |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 211       |
# |    ep_rew_mean          | -123      |
# | time/                   |           |
# |    fps                  | 1066      |
# |    iterations           | 26        |
# |    time_elapsed         | 12        |
# |    total_timesteps      | 13312     |
# | train/                  |           |
# |    approx_kl            | 6.3791313 |
# |    clip_fraction        | 0.934     |
# |    clip_range           | 0.1       |
# |    clip_range_vf        | 1e-05     |
# |    entropy_loss         | -156      |
# |    explained_variance   | -0.00499  |
# |    learning_rate        | 0.1       |
# |    loss                 | 18.4      |
# |    n_updates            | 250       |
# |    policy_gradient_loss | 0.11      |
# |    std                  | 2.43e+17  |
# |    value_loss           | 103       |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 211       |
# |    ep_rew_mean          | -123      |
# | time/                   |           |
# |    fps                  | 1065      |
# |    iterations           | 27        |
# |    time_elapsed         | 12        |
# |    total_timesteps      | 13824     |
# | train/                  |           |
# |    approx_kl            | 3.0210524 |
# |    clip_fraction        | 0.933     |
# |    clip_range           | 0.1       |
# |    clip_range_vf        | 1e-05     |
# |    entropy_loss         | -165      |
# |    explained_variance   | 0         |
# |    learning_rate        | 0.1       |
# |    loss                 | 263       |
# |    n_updates            | 260       |
# |    policy_gradient_loss | 0.16      |
# |    std                  | 2.46e+18  |
# |    value_loss           | 565       |
# ---------------------------------------
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 71
#      68 print("Training with hyperparameters:", hyperparams)
#      70 start_time = time.time()
# ---> 71 model.learn(total_timesteps=100000) #100 thousand steps
#      72 end_time = time.time()
#      74 training_time = end_time - start_time
#
# File ~/anaconda3/envs/rl2/lib/python3.8/site-packages/stable_baselines3/ppo/ppo.py:307, in PPO.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     297 def learn(
#     298     self: SelfPPO,
#     299     total_timesteps: int,
#    (...)
#     304     progress_bar: bool = False,
#     305 ) -> SelfPPO:
# --> 307     return super().learn(
#     308         total_timesteps=total_timesteps,
#     309         callback=callback,
#     310         log_interval=log_interval,
#     311         tb_log_name=tb_log_name,
#     312         reset_num_timesteps=reset_num_timesteps,
#     313         progress_bar=progress_bar,
#     314     )
#
# File ~/anaconda3/envs/rl2/lib/python3.8/site-packages/stable_baselines3/common/on_policy_algorithm.py:269, in OnPolicyAlgorithm.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     266         self.logger.record("time/total_timesteps", self.num_timesteps, exclude="tensorboard")
#     267         self.logger.dump(step=self.num_timesteps)
# --> 269     self.train()
#     271 callback.on_training_end()
#     273 return self
#
# File ~/anaconda3/envs/rl2/lib/python3.8/site-packages/stable_baselines3/ppo/ppo.py:208, in PPO.train(self)
#     205 if self.use_sde:
#     206     self.policy.reset_noise(self.batch_size)
# --> 208 values, log_prob, entropy = self.policy.evaluate_actions(rollout_data.observations, actions)
#     209 values = values.flatten()
#     210 # Normalize advantage
#
# File ~/anaconda3/envs/rl2/lib/python3.8/site-packages/stable_baselines3/common/policies.py:707, in ActorCriticPolicy.evaluate_actions(self, obs, actions)
#     705     latent_pi = self.mlp_extractor.forward_actor(pi_features)
#     706     latent_vf = self.mlp_extractor.forward_critic(vf_features)
# --> 707 distribution = self._get_action_dist_from_latent(latent_pi)
#     708 log_prob = distribution.log_prob(actions)
#     709 values = self.value_net(latent_vf)
#
# File ~/anaconda3/envs/rl2/lib/python3.8/site-packages/stable_baselines3/common/policies.py:664, in ActorCriticPolicy._get_action_dist_from_latent(self, latent_pi)
#     661 mean_actions = self.action_net(latent_pi)
#     663 if isinstance(self.action_dist, DiagGaussianDistribution):
# --> 664     return self.action_dist.proba_distribution(mean_actions, self.log_std)
#     665 elif isinstance(self.action_dist, CategoricalDistribution):
#     666     # Here mean_actions are the logits before the softmax
#     667     return self.action_dist.proba_distribution(action_logits=mean_actions)
#
# File ~/anaconda3/envs/rl2/lib/python3.8/site-packages/stable_baselines3/common/distributions.py:164, in DiagGaussianDistribution.proba_distribution(self, mean_actions, log_std)
#     156 """
#     157 Create the distribution given its parameters (mean, std)
#     158
#    (...)
#     161 :return:
#     162 """
#     163 action_std = th.ones_like(mean_actions) * log_std.exp()
# --> 164 self.distribution = Normal(mean_actions, action_std)
#     165 return self
#
# File ~/anaconda3/envs/rl2/lib/python3.8/site-packages/torch/distributions/normal.py:56, in Normal.__init__(self, loc, scale, validate_args)
#      54 else:
#      55     batch_shape = self.loc.size()
# ---> 56 super().__init__(batch_shape, validate_args=validate_args)
#
# File ~/anaconda3/envs/rl2/lib/python3.8/site-packages/torch/distributions/distribution.py:62, in Distribution.__init__(self, batch_shape, event_shape, validate_args)
#      60         valid = constraint.check(value)
#      61         if not valid.all():
# ---> 62             raise ValueError(
#      63                 f"Expected parameter {param} "
#      64                 f"({type(value).__name__} of shape {tuple(value.shape)}) "
#      65                 f"of distribution {repr(self)} "
#      66                 f"to satisfy the constraint {repr(constraint)}, "
#      67                 f"but found invalid values:\n{value}"
#      68             )
#      69 super().__init__()
#
# ValueError: Expected parameter loc (Tensor of shape (128, 4)) of distribution Normal(loc: torch.Size([128, 4]), scale: torch.Size([128, 4])) to satisfy the constraint Real(), but found invalid values:
# tensor([[nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan]], grad_fn=<AddmmBackward0>)
